# %%
import pandas as pd
import json
import requests
from pprint import pprint
import re

# %%
url = "https://public.opendatasoft.com/api/records/1.0/search/?dataset=global-shark-attack&q=&rows=1000&facet=date&facet=type&facet=country&facet=area&facet=activity&facet=sex&facet=age&facet=fatal_y_n&facet=time&facet=species"

response = requests.get(url)    # Will get a HTTP Status code (response object)

response_json = response.json()

# %%
# Just want to pull records 
records = response_json['records']

# Look at first record
pprint(len(records))
# Out:
# 1000

# %%
# Need to make a list of the field dictionaries
records_fields = [x["fields"] for x in records]

# Check list to make sure correct info was collected
records_fields[0:1]
# Out:
# [{'activity': 'Surfing',
#   'location': 'Jupiter Island, Martin County',
#   'sex': 'M',
#   'year': '2023',
#   'injury': 'Injury to lower leg',
#   'case_number': '2023.02.19.a',
#   'time': '17h30',
#   'name': 'Bert Krebs',
#   'investigator_or_source': 'CBS, 2/22/2023',
#   'age': '60',
#   'date': '2023-02-19',
#   'type': 'Unprovoked',
#   'area': 'Florida',
#   'country': 'USA',
#   'fatal_y_n': 'N'}]

# %%
# Make a dataframe
df = pd.DataFrame(records_fields)
df.head(5)
# Out:
#                            activity                       location sex  year  \
# 0                           Surfing  Jupiter Island, Martin County   M  2023
# 1                      Spearfishing                     Ura Estate   M  2023
# 2  Floating in inflatable pool ring     Beds, Wylie Bay, Esperance   F  2022
# 3                               NaN                       Karratha   M  2021
# 4                           Surfing         Cacimba do Padre Beach   M  2021
#
#                           injury   case_number   time             name  \
# 0            Injury to lower leg  2023.02.19.a  17h30       Bert Krebs
# 1                   Questionable    2023.02.19  07h20  Samuela Kiniboi
# 2                   Torso bitten  2022.02.10.R  11h15  Jacquelin Morle
# 3             Laceration to foot  2021.04.24.a  15h40             male
# 4  Puncture wounds to right hand    2021.01.22    NaN    Sergo Noronha
#
#             investigator_or_source   age  ...               area    country  \
# 0                   CBS, 2/22/2023    60  ...            Florida        USA
# 1              Fiji Sun, 2/25/2023    41  ...     Taveuni Island       FIJI
# 2  K. McMurray, TrackingSharks.com  20.0  ...  Western Australia  AUSTRALIA
# 3  K. McMurray, TrackingSharks.com   NaN  ...  Western Australia  AUSTRALIA
# 4  K. McMurray, TrackingSharks.com  52.0  ...         Pernambuco     BRAZIL
#
#   fatal_y_n                                       href_formula original_order  \
# 0         N                                                NaN            NaN
# 1         N                                                NaN            NaN
# 2         N  http://sharkattackfile.net/spreadsheets/pdf_di...           6734
# 3         N  http://sharkattackfile.net/spreadsheets/pdf_di...           6649
# 4         N  http://sharkattackfile.net/spreadsheets/pdf_di...           6624
#
#    case_number1      species  \
# 0           NaN          NaN
# 1           NaN          NaN
# 2    2022.02.05  White shark
# 3    2021.04.19          NaN
# 4  2021.01.13.b          NaN
#
#                                                 href  \
# 0                                                NaN
# 1                                                NaN
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                         pdf  case_number0
# 0                       NaN           NaN
# 1                       NaN           NaN
# 2      2022.02.05-Morle.pdf    2022.02.05
# 3   2021.04.19-Karratha.pdf    2021.04.19
# 4  2021.01.13.b-Noronha.pdf  2021.01.13.b
#
# [5 rows x 22 columns]

# %%
# Make a cut pd with the fields: ["activity", "location", "sex", "year", "injury", "case_number", "time", "age", "type", "area", "country", "fatal_y_n", "species"]
df_cut = df.loc[:, ["activity", "location", "sex", "year", "injury", "case_number", "time", "age", "type", "area", "country", "fatal_y_n", "species"]]
df_cut.head(5)
# Out:
#                            activity                       location sex  year  \
# 0                           Surfing  Jupiter Island, Martin County   M  2023
# 1                      Spearfishing                     Ura Estate   M  2023
# 2  Floating in inflatable pool ring     Beds, Wylie Bay, Esperance   F  2022
# 3                               NaN                       Karratha   M  2021
# 4                           Surfing         Cacimba do Padre Beach   M  2021
#
#                           injury   case_number   time   age          type  \
# 0            Injury to lower leg  2023.02.19.a  17h30    60    Unprovoked
# 1                   Questionable    2023.02.19  07h20    41  Questionable
# 2                   Torso bitten  2022.02.10.R  11h15  20.0    Unprovoked
# 3             Laceration to foot  2021.04.24.a  15h40   NaN    Unprovoked
# 4  Puncture wounds to right hand    2021.01.22    NaN  52.0    Unprovoked
#
#                 area    country fatal_y_n      species
# 0            Florida        USA         N          NaN
# 1     Taveuni Island       FIJI         N          NaN
# 2  Western Australia  AUSTRALIA         N  White shark
# 3  Western Australia  AUSTRALIA         N          NaN
# 4         Pernambuco     BRAZIL         N          NaN

# %% [markdown]
# # Pie Chart looking at shark attacks by sex

# %%
df_sex = df_cut.groupby(["sex"])["sex"].count()
colors = ["pink", "steelblue"]
df_sex.plot(kind="pie", ylabel="", autopct='%1.0f%%', colors=colors, legend=True, title = "Sex of 'Victims'")
# Out:
# <AxesSubplot:title={'center':"Sex of 'Victims'"}>

# %% [markdown]
# # Clean up Species

# %%
# Replace na's with 'unknown'
df_cut["species"].fillna("unknown", inplace=True)
df_cut
# Out:
#                              activity                            location sex  \
# 0                             Surfing       Jupiter Island, Martin County   M
# 1                        Spearfishing                          Ura Estate   M
# 2    Floating in inflatable pool ring          Beds, Wylie Bay, Esperance   F
# 3                                 NaN                            Karratha   M
# 4                             Surfing              Cacimba do Padre Beach   M
# ..                                ...                                 ...  ..
# 995                          Swimming        Second Beach, Port St. Johns   M
# 996                           Surfing                    Teahupoo, Tahiti   M
# 997               Playing in the surf  North Topsail Beach, Onslow County   F
# 998                            Wading    New Smyrna Beach, Volusia County   M
# 999                           Surfing                       Robberg Beach   M
#
#      year                            injury    case_number       time   age  \
# 0    2023               Injury to lower leg   2023.02.19.a      17h30    60
# 1    2023                      Questionable     2023.02.19      07h20    41
# 2    2022                      Torso bitten   2022.02.10.R      11h15  20.0
# 3    2021                Laceration to foot   2021.04.24.a      15h40   NaN
# 4    2021     Puncture wounds to right hand     2021.01.22        NaN  52.0
# ..    ...                               ...            ...        ...   ...
# 995  2012                             FATAL   2012.01.18.b      15h40    25
# 996  2011           No injury, board bitten  2011.08.17.b.      15h30    32
# 997  2011                      Ankle bitten     2011.06.29  Afternoon    10
# 998  2011            Puncture wound to calf   2011.06.06.R      12h00    19
# 999  2011  No injury, board bumped by shark     2011.06.01        NaN    33
#
#              type                   area           country fatal_y_n  \
# 0      Unprovoked                Florida               USA         N
# 1    Questionable         Taveuni Island              FIJI         N
# 2      Unprovoked      Western Australia         AUSTRALIA         N
# 3      Unprovoked      Western Australia         AUSTRALIA         N
# 4      Unprovoked             Pernambuco            BRAZIL         N
# ..            ...                    ...               ...       ...
# 995    Unprovoked  Eastern Cape Province      SOUTH AFRICA         Y
# 996    Unprovoked        Society Islands  FRENCH POLYNESIA         N
# 997    Unprovoked         North Carolina               USA         N
# 998    Unprovoked                Florida               USA         N
# 999    Unprovoked  Western Cape Province      SOUTH AFRICA         N
#
#                              species
# 0                            unknown
# 1                            unknown
# 2                        White shark
# 3                            unknown
# 4                            unknown
# ..                               ...
# 995  Thought to involve a bull shark
# 996                  Grey reef shark
# 997                   Bull shark, 6'
# 998                   3' to 4' shark
# 999                      White shark
#
# [1000 rows x 13 columns]

# %%
# Examine all the possible species
df_cut["species"].unique()
# Out:
# array(['unknown', 'White shark', 'Bull shark pup', 'Cookiecutter shark',
#        'Spinner shark', "Tiger shark, 10' to 12'", "Nurse shark, 5'",
#        'Nurse shark', 'Spinner shark, 4 to 5 feet', "Nurse shark, 2'",
#        'Wobbegong shark', "Bull shark, 8'", 'Lemon shark, 3.5 m',
#        '2 m shark', '1m shark', "4' to 6' shark", 'Galapagos shark',
#        'Wobbegong, 2m', "4' shark", "Tiger shark, 8'",
#        "Porbeagle shark, 7'", 'No shark involvement', '18 to 24 shark',
#        "5' shark", 'Shark involvement not confirmed', "6' to 8' shark",
#        'Shark involvement prior to death not confirmed', '80 kg shark',
#        'Lemon shark', "Tiger shark, 12'", 'Questionable Incident',
#        '1.5 m shark', 'White shark, 3m',
#        "0.9 m to 1.2 m [3' to 4'] white shark",
#        "Tiger shark, 2.4 m to 3 m [8' to 10']",
#        "White shark, 4.5 m [14'9]", 'Invalid',
#        'Thought to involve a Zambesi shark', "Mako shark, 2 m [6.75']",
#        "3' to 4' shark", 'Grey reef shark, 1.5 m',
#        "3 m to 4 m [10' to 13'] white shark", "1.5 m [5'] shark",
#        'a small shark', 'White shark (tooth fragment recovered)',
#        'Though to involve a tiger shark', "5.5 m [18'] white shark",
#        "1.2 m [4'] shark", 'Mako shark', 'Questionable incident',
#        '170-kg, 2.8 m shark', "7' female shark",
#        'Shark had a very large girth', '3 m white shark',
#        'small blue shark', "2.5 m [8.25'] shark",
#        "3 m to 4 m [10' to 13'] shark",
#        'Shark involvement prior to death was not confirmed',
#        "White shark, 3.7 m [12']", "1.5 to 2 m [5' to 6.75'] shark",
#        "White shark, 5.8 m [19']", "Carpet shark, 10'",
#        "7' to 8' bull shark", 'Tiger shark', "2 m [6'9] shark",
#        "White shark, 4 m [13']", "White shark, 4 to 5 m [13' to 16.5']",
#        'A pack of 6 sharks', "1.5 m to 2.1 m  [5' to 7'] shark",
#        "4.6 m [15'] shark", 'Blacktip or spinner shark',
#        'White shark, 3 m', '193-lb shark', "White shark, 15'2",
#        'Shark involvement prior to deaths was not confirmed',
#        "3.5 m [11.5'] shark", "Hammerhead shark, 3 m [10']",
#        "Tiger shark, 3.7 m [12']", "Tiger shark 4.3 m [14']",
#        "3.7 m [12'] shark", "Hammerhead shark, 5.2 m [17']",
#        'Several sharks involved',
#        'Shark seen feeding on turtle scraps thrown overboard prior to incident.',
#        "2.4 m [8']  shark", 'sand shark', "Bull shark, 4 m [13']",
#        "Mako shark (aka bonito shark) 1.2 m [4']",
#        '2 days later a 600-lb shark was caught 100 yards from the site',
#        "4.4 m [14'] shark", 'Questionable',
#        "3.7 m to 4.3 m [12' to 14']  shark",
#        'Shark involvement prior to death unconfirmed', 'A small shark',
#        'Bronze whaler', 'Epaulette shark', 'Broadnose seven gill shark',
#        'Blacktip whaler,      Carcharhinus tilstoni, 2m',
#        "Bull shark, 6.5 to 10 '", 'Angel shark', '3.4 m tiger shark',
#        "14' white shark", 'Tiger shark, 4m to 5m',
#        'Salmon shark, juvenile', 'White shark, 2.5 m', '2m shark',
#        'White shark, 4.5 m', 'White shark, 3.5m', "8' shark",
#        'Caribbean reef shark', 'Blue shark', "Bull shark, 4' to 5'",
#        'Grey reef shark, 2 m', "4' to 5' shark", 'White shark, 2m to 3 m',
#        "Bull shark, 5'", "6' shark", "Tiger shark, 6'",
#        'small blacktip shark?', 'Grey nurse shark', "3' shark",
#        "6' shark, possibly a blactip or spinner shark", 'White shark, 2m',
#        'Tiger shark, 12', 'Bull shark', "3'  shark",
#        'Oceanic whitetip sharks were in the vicinity', "9.5' shark?",
#        '24 to 30 shark', "3' to 3.5' shark", 'Bronze whaler shark, 2 m',
#        "3 m to 4 m [10' to 13']  white shark", 'Raggedtooth shark',
#        "Thought to involve a 2 m [6.75'] grey nurse shark",
#        "Bronze whaler shark, 2.5 m [8.25']", 'Blacktip shark',
#        'Miami, a 60 cm blacktip  shark and two 60 cm bamboo catsharks',
#        'Tiger shark, 2m to 3m', "1.8 m [6'] shark", "2.7 m [9'] shark",
#        "4 m [13'] white shark",
#        "1.8 m [6'] blacktip shark or Caribbean reef shark",
#        "Tiger shark, 3 to 4 m [10' to 13']",
#        "1.2 m to 1.5 m [4' to 5'] shark", '2 m hammerhead',
#        "Two sharks seen in vicinity: 2.4 m & 4.25 m  [8' & 14'] TL",
#        'Tiger shark, 2m', '3.5 m white shark', "Tiger shark, 5 m [16.5']",
#        "1.8 m [6'] dogfish",
#        'Said to involve a white shark but shark involvement not confirmed',
#        'Whale shark', 'Bronze whaler shark', "White shark, 6 m [20']",
#        "7' shark", "Alleged to involve a White shark, 7.6 m [25']",
#        "White shark, 1.5 m [5'] k", "Silky shark, 1.9 m [6.5']",
#        "1.8 m to 2.4 m  [6' to 8'] shark",
#        'Possibly a bronze whaler shark',
#        "Next morning a 3 m [10'] shark was caught that had Andrews' leg in its gut",
#        'Oceanic whitetip shar,; identified by Dr. W.C. Schoeder on photograph & Dr. L.P. L. Schultz on sketch by observer',
#        "Grey reef shark, 1.8 m [6'] grey reef shark, identified by Dr. L.P. L. Schultz based on photographs; identified as C. melanopterus by Stewart",
#        "Bronze whaler shark, 3.7 m [12'] identified by G.P. Whitley based on description",
#        "1.2 m [4'], possibly  larger shark", "4.9 m [16'] shark",
#        "2.1 m [7'] shark", "1.5 m to 1.8 m [5' to 6'] sharks",
#        'Mako shark, 125-lb', 'Porbeagle or white shark',
#        'Survivors said 2 species of sharks were involved:  oceanic whitetip sharks and another species',
#        "White shark,4.6 m [15']", "Wobbegong shark, 6'", '2.13 m shark',
#        'Most likely, a small shark',
#        "Bull sharks to 1.5 m [5']  in length", 'whaler shark',
#        "Tiger shark, 9' to 10'", "Tiger shark, 3.4 m [11']",
#        'Species unknown, possibly a white shark', '3.5 m shark',
#        "Comrades saw shark's tail appear about 5' away",
#        "Thought to involve a 2.6 m [8.5'] white shark", "12' shark",
#        'The fish was harpooned, dried, and presented to the sailor, who went round Europe exhibiting it  It was said to be 20 feet long.',
#        'A large hammerhead shark', 'Blue pointer',
#        'Said to involve a bull shark', 'Injuries not caused by a shark',
#        'Sand tiger shark', "Tiger shark, 13'", "Bull shark, 6'",
#        "Tiger shark, 10'", '3 m shark', "Spinner shark, 5'",
#        'Bull shark, 2.5 m', "Bull shark, 6' to 8'", "10' shark",
#        '2.5 m shark', 'Lemon shark, 2.5m to 3m', 'Possibly a bull shark',
#        'White shark, 7m', 'Zambesi shark', 'Bull shark, 2m',
#        'Shark involvement questionable', 'reef shark, 1.8m',
#        'Reported by media as shark attack, but shark involvement prior to death was not confirmed',
#        "Nurse shark, 2' to 3'",
#        'A 10-year-old 94-pound pregnant blacktip reef shark',
#        "Bronze whaler shark, 6'",
#        'Unknown, but it was reported that a shark tooth was recovered from the wound',
#        "2.4 m [8'] shark", 'small sharks', 'Unidentified species',
#        "Tiger shark, 1.5 m [5']k", 'Nurse shark, 1m',
#        "Porbeagle shark, 3 m [10']rk", "White shark, 4.9 m [16']",
#        "Tiger shark, 1.8 m to 2.4 m [6' to 8']", "Blacktip shark, 2'",
#        "Tiger shark, 3 m [10']", 'Hammerhead shark',
#        "White shark, 5 m to 6 m [16.5' to 20']",
#        "On 11-Jan-1994, his remains washed ashore. A 2.4 m [8'] tiger shark thought to be involved",
#        "5.5 m to 6 m [18' to 20']  white shark",
#        "Two 3 m [10'] oceanic whitetip sharks",
#        'White shark, identification by K. Nakaya', 'Grey reef shark',
#        "1.8 m [6'] blacktip shark", '1.5 m copper shark',
#        "1.5 m [5'] blacktip shark", 'Sandtiger shark', "6', 100-lb shark",
#        "3.5 m [11.5'] white shark", 'Sevengill shark', 'sandshark',
#        'Thought to involve a blacktip shark', 'White shark, 4.8 m',
#        "White shark, 5.5 m to 6 m [18' to 20']",
#        "2 m to 2.5 m [6.75'  to 8.25'] shark", 'Carpet shark',
#        ">2.4 m [8'] shark",
#        'White shark, identified by tooth fragments in surfboard',
#        "1.8 m [6'], 180-lb shark", "2.1 m to 2.4 m  [7' to 8'] shark",
#        "Zambesi shark, 1.8 m [6']", "White shark, 2.1 m [7']", 'Unknown',
#        "Grey nurse shark,  3 m [10']", 'Hammerhead shark, 500-llb',
#        "Hammerhead shark, 1.8 m [6']", 'Blacktail reef shark',
#        "1.8 to 2.1 m [6' to 7'] shark", 'Tiger shark, <2 m TL',
#        'Tooth fragments recovered from hull',
#        "White shark, 3.7 m [12'], 500 to 500-kg [1,200 lb], identified by W. C. Shroeder based on tooth fragment ebedded in gunwale",
#        "Hammerhead shark, 5'", "17' white shark",
#        "2.7 m [9'] shark with black-tipped pectoral fins",
#        "Tiger shark, 14'", '>1.6 m shark',
#        "Blue shark, 8' [2.4 m], 500-lb",
#        "4 m [13'] shark seen in vicinity", "4 m [13'] shark",
#        "Tiger shark, 4 m [13'] female", 'Said to be a “small shark”',
#        'Allegedly a 33-foot shark', "Blacktip shark, 5'",
#        'Silvertip shark', 'Juvenile nurse shark', "White shark, 13'",
#        'Oceaniic whitetip shark/tiger shark, 2m shark',
#        "Tiger shark, 15'", 'Tiger shark, 2 to 2.5m', "7' to 8' shark",
#        'Shark involvement unconfirmed but considered probable',
#        'Bull shark, 3.5 m',
#        'Reported as shark attacks but injuries caused by toadfish',
#        "Mako shark, 7'", 'Reef shark x 2', 'White shark, 3.5 m',
#        'White shark, 3 to 3.5m', 'dogfish shark', "Silky shark, 6.5'",
#        'small nurse shark', '1.8 m shark', "2 white shark: 13' & 98",
#        'reef shark', 'Tiger shark?', 'Possibly a 3 m bull shark',
#        'Tiger shark, 3m', "White shark, 15' to 16'", "Lemon shark, 4'",
#        "Sandtiger shark, 8'",
#        'Shark involvement probable, but not confirmed',
#        "Blacktip shark, 4'", 'White shark, 4m to 5m',
#        "2' to 3' reef shark", 'White shark, 5m', "18' white shark",
#        "2.5 m [8.25'] bull shark",
#        'Thought to involve a 2.5 m bull or tiger shark', '1 m  shark',
#        "12' sandtiger shark", "3 m [10'] shark",
#        "Blacktip shark, 1.2 m to 1.8 m [4' to 6']",
#        "1.8 m [6'] shark, possibly a blacktip",
#        'Thought to involve an oceanic whitetip shark or a white shark',
#        '1 m shark', "Tiger shark, 4.5 m [14'9]",
#        "1.2 m [4'] spinner shark", '4.9 m white shark',
#        "2.5 m [8.25'] white shark", '>2 m shark', "6 m [20'] white shark",
#        'Grey nurse shark, 2 m', '4.5 m to 5.5m white shark',
#        '6 m  white shark', 'Juvenile dusky or blacktip shark',
#        'Bull shark, 8', "White shark, 3 m [10'] k",
#        "Mako shark, 3 m [10']", 'Juvenile dusky shark',
#        '90-kg blackfin shark', 'Nurse shark, 1 m', "0.9 m [3'] shark",
#        'Dusky shark, 1 m', 'Possibly a broadnose 7-gill shark',
#        "Bronze whaler shark, 2.4 m [8'] Identified by Clyde Buttery",
#        '> 3 m shark',
#        "White shark, 3 m [10'], tooth fragment from wounds identified as that of a white shark",
#        "Lemon shark, 1.8 m [6'] male, N. breviostris, identified by W.A. Stark II, later the same day a 6'8 pregnant female lemon shark bit the bow of the boat",
#        "3.5 m [11'6] shark captured", "2.4 m  [8'] shark",
#        'small brown-colored shark',
#        "Leopard shark, 3' Triakis semifasciata, identified by J.W. DeWitt (1955)",
#        ">6.7 m [22']  shark", 'Attacked by a number of sharks',
#        "Said to be 6.4 m [21'] shark", 'Basking shark',
#        "Tiger shark, 2.4 m [8']", 'Remains recovered from 3 sharks',
#        'Shark involvement probable', 'Shortfin mako shark, 175-lb',
#        "15' shark", 'said to involve 2.5 m hammerhead sharks',
#        'Shovelnose guitarfish, adult male', 'No shark invovlement',
#        'Possibly a juvenile blacktip shark',
#        'Oceanic whitetip shark, 1.8 to 2 m', 'Lemon shark pup',
#        'Tiger shark, 1.5 m', "4' shark?",
#        "Thought to involve a 3' to 4' shark, but shark involvement not confirmed",
#        'Small bull shark', 'Raggedtooth shark, 1.5 m',
#        'Bronze whaler shark, 3m', 'White shark, 2.7 m',
#        'Thought to involve a bull shark'], dtype=object)

# %%
# Clean up data by finding key words and replacing the species information 
# For example, any species that has bull in it will just be replaced with "bull shark"
# any species that has "Great" and "white" will be replaced with "Great white"
# Any species with "Tiger" will be replaced with "Tiger"
# Hammerhead, Mako, Spinner, Nurse, Cookiecutter, Blacktip, Raggedtooth, Zambesi, Grey reef shark, dogfish, wobbegong
# If "or" than species will be replaced with "unknown"
#

# %%
# Function to search for great white buzz words and replace them with "great white" also included C. obscurus (dusky)
def whiteshark(species):
    p = '[Ww]hite'
    if re.search('[Ww]hitetip', species):   # Need to watch out for whitetip species (not great whites)
        return "whitetip"
    elif re.search(p, species):     # great white sharks are just called "white sharks" in much of the world
        return "great white"
    elif re.search('C. obscurus', species):     # Replace species name with common name: dusky
        return 'dusky'
    #elif re.search('?', species) or re.search('\sor\s', species):   # If there is a question mark or an "or" than replace with "unknown"
        #return 'unknown'
    return species  # else just return the species listed for further inspection later

# %%
df_cut["species"] = df_cut["species"].apply(whiteshark)
df_cut
# Out:
#                              activity                            location sex  \
# 0                             Surfing       Jupiter Island, Martin County   M
# 1                        Spearfishing                          Ura Estate   M
# 2    Floating in inflatable pool ring          Beds, Wylie Bay, Esperance   F
# 3                                 NaN                            Karratha   M
# 4                             Surfing              Cacimba do Padre Beach   M
# ..                                ...                                 ...  ..
# 995                          Swimming        Second Beach, Port St. Johns   M
# 996                           Surfing                    Teahupoo, Tahiti   M
# 997               Playing in the surf  North Topsail Beach, Onslow County   F
# 998                            Wading    New Smyrna Beach, Volusia County   M
# 999                           Surfing                       Robberg Beach   M
#
#      year                            injury    case_number       time   age  \
# 0    2023               Injury to lower leg   2023.02.19.a      17h30    60
# 1    2023                      Questionable     2023.02.19      07h20    41
# 2    2022                      Torso bitten   2022.02.10.R      11h15  20.0
# 3    2021                Laceration to foot   2021.04.24.a      15h40   NaN
# 4    2021     Puncture wounds to right hand     2021.01.22        NaN  52.0
# ..    ...                               ...            ...        ...   ...
# 995  2012                             FATAL   2012.01.18.b      15h40    25
# 996  2011           No injury, board bitten  2011.08.17.b.      15h30    32
# 997  2011                      Ankle bitten     2011.06.29  Afternoon    10
# 998  2011            Puncture wound to calf   2011.06.06.R      12h00    19
# 999  2011  No injury, board bumped by shark     2011.06.01        NaN    33
#
#              type                   area           country fatal_y_n  \
# 0      Unprovoked                Florida               USA         N
# 1    Questionable         Taveuni Island              FIJI         N
# 2      Unprovoked      Western Australia         AUSTRALIA         N
# 3      Unprovoked      Western Australia         AUSTRALIA         N
# 4      Unprovoked             Pernambuco            BRAZIL         N
# ..            ...                    ...               ...       ...
# 995    Unprovoked  Eastern Cape Province      SOUTH AFRICA         Y
# 996    Unprovoked        Society Islands  FRENCH POLYNESIA         N
# 997    Unprovoked         North Carolina               USA         N
# 998    Unprovoked                Florida               USA         N
# 999    Unprovoked  Western Cape Province      SOUTH AFRICA         N
#
#                              species
# 0                            unknown
# 1                            unknown
# 2                        great white
# 3                            unknown
# 4                            unknown
# ..                               ...
# 995  Thought to involve a bull shark
# 996                  Grey reef shark
# 997                   Bull shark, 6'
# 998                   3' to 4' shark
# 999                      great white
#
# [1000 rows x 13 columns]

# %%
# The sharks list was created by combing through the species.unique() 
sharks = ['hammerhead', 'mako' 'spinner', 'nurse', 'cookiecutter', 'blacktip', 'raggedtooth', 'zambesi', 'reef', 'dogfish', 'wobbegong', "tiger", "bull", "bronze whaler", "sand", "lemon", "blue", "Port Jackson", "thresher", "shovelnose", "porbeagle", "dusky", "banjo", "silvertip", "whitetip", "dusky", "great white"]

# Function created to check if a species is from the approved list; if it is not, then it is replaced with 'unknown'
def clean_shark_species(species):
    for p in sharks:
        if re.search(p, species) or re.search(p.capitalize(), species):
            return p.lower()
    return "unknown"

# %%
# Apply filtering function to the species column 
df_cut["species"] = df_cut["species"].apply(clean_shark_species)
df_cut
# Out:
#                              activity                            location sex  \
# 0                             Surfing       Jupiter Island, Martin County   M
# 1                        Spearfishing                          Ura Estate   M
# 2    Floating in inflatable pool ring          Beds, Wylie Bay, Esperance   F
# 3                                 NaN                            Karratha   M
# 4                             Surfing              Cacimba do Padre Beach   M
# ..                                ...                                 ...  ..
# 995                          Swimming        Second Beach, Port St. Johns   M
# 996                           Surfing                    Teahupoo, Tahiti   M
# 997               Playing in the surf  North Topsail Beach, Onslow County   F
# 998                            Wading    New Smyrna Beach, Volusia County   M
# 999                           Surfing                       Robberg Beach   M
#
#      year                            injury    case_number       time   age  \
# 0    2023               Injury to lower leg   2023.02.19.a      17h30    60
# 1    2023                      Questionable     2023.02.19      07h20    41
# 2    2022                      Torso bitten   2022.02.10.R      11h15  20.0
# 3    2021                Laceration to foot   2021.04.24.a      15h40   NaN
# 4    2021     Puncture wounds to right hand     2021.01.22        NaN  52.0
# ..    ...                               ...            ...        ...   ...
# 995  2012                             FATAL   2012.01.18.b      15h40    25
# 996  2011           No injury, board bitten  2011.08.17.b.      15h30    32
# 997  2011                      Ankle bitten     2011.06.29  Afternoon    10
# 998  2011            Puncture wound to calf   2011.06.06.R      12h00    19
# 999  2011  No injury, board bumped by shark     2011.06.01        NaN    33
#
#              type                   area           country fatal_y_n  \
# 0      Unprovoked                Florida               USA         N
# 1    Questionable         Taveuni Island              FIJI         N
# 2      Unprovoked      Western Australia         AUSTRALIA         N
# 3      Unprovoked      Western Australia         AUSTRALIA         N
# 4      Unprovoked             Pernambuco            BRAZIL         N
# ..            ...                    ...               ...       ...
# 995    Unprovoked  Eastern Cape Province      SOUTH AFRICA         Y
# 996    Unprovoked        Society Islands  FRENCH POLYNESIA         N
# 997    Unprovoked         North Carolina               USA         N
# 998    Unprovoked                Florida               USA         N
# 999    Unprovoked  Western Cape Province      SOUTH AFRICA         N
#
#          species
# 0        unknown
# 1        unknown
# 2    great white
# 3        unknown
# 4        unknown
# ..           ...
# 995         bull
# 996         reef
# 997         bull
# 998      unknown
# 999  great white
#
# [1000 rows x 13 columns]

# %%
# Check what unique values are now present 
df_cut['species'].unique()
# Out:
# array(['unknown', 'great white', 'bull', 'cookiecutter', 'tiger', 'nurse',
#        'wobbegong', 'lemon', 'porbeagle', 'zambesi', 'reef', 'blue',
#        'blacktip', 'hammerhead', 'sand', 'bronze whaler', 'whitetip',
#        'raggedtooth', 'dogfish', 'silvertip', 'dusky', 'shovelnose'],
#       dtype=object)

# %% [markdown]
# # Clean up Countries

# %%
# Capitalize all countries so theyre the same 
df_cut["country"].str.upper()
# Out:
# 0                   USA
# 1                  FIJI
# 2             AUSTRALIA
# 3             AUSTRALIA
# 4                BRAZIL
#              ...
# 995        SOUTH AFRICA
# 996    FRENCH POLYNESIA
# 997                 USA
# 998                 USA
# 999        SOUTH AFRICA
# Name: country, Length: 1000, dtype: object

# %% [markdown]
# # Clean up activities

# %%
df_cut["type"].unique()
# Out:
# array(['Unprovoked', 'Questionable', 'Watercraft', 'Provoked', 'Invalid',
#        'Sea Disaster', 'Boat', nan], dtype=object)

# %% [markdown]
# ### Identify invalid interactions (shark involvement unlikely)

# %%
# df_cut[df_cut["type"]=="Watercraft"]
# Watercraft interactions are when people are in boats and interact with sharks
# Eliminating if injury is unrelated to shark damaging someone or a boat
# 15, 28, 79, 123, 158, 644, 645, 674, 676, 679, 872, 902, 960

# %%
df_cut[df_cut["type"]=="Questionable"]
# Remove interactions with too little information
# 1, 246
# Out:
#          activity    location sex  year  \
# 1    Spearfishing  Ura Estate   M  2023
# 246      Kayaking         NaN   M  2019
#
#                                               injury case_number   time   age  \
# 1                                       Questionable  2023.02.19  07h20    41
# 246  Partial remains recovered 12/26/2019 from shark  2019.12.21    NaN  70.0
#
#              type            area         country fatal_y_n  species
# 1    Questionable  Taveuni Island            FIJI         N  unknown
# 246  Questionable             NaN  REUNION ISLAND         F    tiger

# %%
df_invalid= df_cut[df_cut["type"]=="Invalid"]
# 42, 45, 50, 54, 161, 64, 66, 74, 80, 103, 120, 141, 152, 159, 163, 187, 222, 224, 310, 314, 320, 358, 359, 380, 393, 402, 414, 427, 442, 447, 451, 507, 545, 548, 593, 600, 636, 649, 652, 658, 672, 691, 761, 783, 868, 875, 898, 913, 926,  

df_invalid.to_csv("Resources/type_invalid.csv")

# %%
# Checked injury to identify legitimate
#df_cut[df_cut["type"]=="Sea Disaster"]

# %%
# Make a list of the rows to drop
# Make a new df with rows not in the drop list
drop_values = [1, 246, 15, 28, 79, 123, 158, 644, 645, 674, 676, 679, 872, 902, 960, 42, 45, 50, 54, 161, 64, 66, 74, 80, 103, 120, 141, 152, 159, 163, 187, 222, 224, 310, 314, 320, 358, 359, 380, 393, 402, 414, 427, 442, 447, 451, 507, 545, 548, 593, 600, 636, 649, 652, 658, 672, 691, 761, 783, 868, 875, 898, 913, 926]
df_real = df_cut[df_cut.index.isin(drop_values) == False]

# Check out number of remaining incidents
len(df_real)
# Out:
# 936

# %% [markdown]
# ## Clean up Fatal question

# %%
# Create column to indicate the original index
index_og = df_real.index
len(index_og)
# Out:
# 936

# %%
df_real = df_real.reset_index()  # make sure indexes pair with number of rows
df_real["index_original"] = index_og

# %%
# Need to correct fatal column. It sometimes says "unknown" when in fact the injury describes it as a "FATAL" encountour
fatal = []
for index, row in df_real.iterrows():
   
    fatal_y = ["y", "Y", "T", "t"]  # Inconsistent coding for known fatal interactions
    fatal_n = ["n", "N", "F", "f"]  # Inconsistent codfing for known nonfatal iteractions
    if row["fatal_y_n"] in (fatal_y):
        fatal.append("Y")
    elif re.search("FATAL", str(row["injury"])):
        fatal.append("Y")   # "Y" will be code for yes
    elif row["fatal_y_n"] in fatal_n:
        fatal.append("N")   # "N" will be code for no
    else:
        fatal.append("U")   # "U" will stand for unknown
    
print(len(fatal))
# Out:
# 936

# %%
# Set list of fatal codes as the new fatal_y_n column
df_real["fatal_y_n"] = fatal
df_real.head()
# Out:
#    index                          activity                          location  \
# 0      0                           Surfing     Jupiter Island, Martin County
# 1      2  Floating in inflatable pool ring        Beds, Wylie Bay, Esperance
# 2      3                               NaN                          Karratha
# 3      4                           Surfing            Cacimba do Padre Beach
# 4      5                           Surfing  New Smyrna Beach, Volusia County
#
#   sex  year                         injury   case_number   time   age  \
# 0   M  2023            Injury to lower leg  2023.02.19.a  17h30    60
# 1   F  2022                   Torso bitten  2022.02.10.R  11h15  20.0
# 2   M  2021             Laceration to foot  2021.04.24.a  15h40   NaN
# 3   M  2021  Puncture wounds to right hand    2021.01.22    NaN  52.0
# 4   M  2019     3 lacerations to left hand  2019.07.29.b  13h30  18.0
#
#          type               area    country fatal_y_n      species  \
# 0  Unprovoked            Florida        USA         N      unknown
# 1  Unprovoked  Western Australia  AUSTRALIA         N  great white
# 2  Unprovoked  Western Australia  AUSTRALIA         N      unknown
# 3  Unprovoked         Pernambuco     BRAZIL         N      unknown
# 4  Unprovoked            Florida        USA         N      unknown
#
#    index_original
# 0               0
# 1               2
# 2               3
# 3               4
# 4               5

# %% [markdown]
# ## Clean up Time

# %%
def simplify_time(col):
    cleaned_times=[]
    for t in col: 
        if pd.isna(t):
            cleaned_times.append("Unknown")

        else:
            phrases = ["Morning", "Afternoon", "Midday", "Evening", "Night", "Early Morning", "Early morning", "Lunchtime", "Late afternoon", "Mid morning"]
            if re.search("[0-9]+h+[0-9]", t):
                pieces = t.split("h")
                if len(pieces) > 2:
                    print(t)
                if "Between" in pieces:
                    print(t)
            elif t not in phrases:
                print(t)

# %%
simplify_time(df_real["time"])
# Out:
# 2 hours after Opperman
# FATAL  (Wire netting installed at local beaches after this incident.)
# 0830
# --
# Dusk
# 14h00 - 15h00
# 06h00 -- 07h00
# 19h00-20h00
# Nightfall
# 19h00 / 20h00
# Early afternoon
# Between 11h00 & 12h00
# Before daybreak
# 14h00  -15h00
# P.M.
# Dark
# 07h00 - 08h00

# %%
def clean_time(t):
    morning = ["morning", "Morning", "dawn", "Dawn", "Early morning", "Early Morning", "Before daybreak", "06h00 -- 07h00", "07h00 - 08h00", "0830", "<07h30", "Before 10h00"]
    evening = ["evening", "dusk", "Dusk", "Evening", "19h00-20h00", "19h00 / 20h00"]
    night = ["Dark", "Nightfall"]
    midday = ["Between 11h00 & 12h00", "Midday", "midday"]
    afternoon = ["14h00 - 15h00", "Early afternoon", "14h00 - 15h00", "14h00  -15h00"]
    if pd.isna(t):
        return "Unknown"
    
    if t in morning:
        return "Morning"
    elif t in evening:
        return "Evening"
    elif t in night:
        return "Night"
    elif t in midday:
        return "Midday"
    elif t in afternoon:
        return "Afternoon"
    if re.search("[0-9]+h+[0-9]",t):
        h,m = t.split("h")
        t_clean = int(h)*60 + int(m)
        if t_clean <= 240 or t_clean > 1260:
            return "Night"
        elif t_clean <=720:
            return "Morning"
        elif t_clean <= 1020:
            return "Afternoon"
        else:
            return "Evening"
    return "Unknown"

# %%
df_real["time"] = df_real["time"].apply(lambda x: clean_time(str(x)))
df_real
# Out:
#      index                          activity  \
# 0        0                           Surfing
# 1        2  Floating in inflatable pool ring
# 2        3                               NaN
# 3        4                           Surfing
# 4        5                           Surfing
# ..     ...                               ...
# 931    995                          Swimming
# 932    996                           Surfing
# 933    997               Playing in the surf
# 934    998                            Wading
# 935    999                           Surfing
#
#                                location sex  year  \
# 0         Jupiter Island, Martin County   M  2023
# 1            Beds, Wylie Bay, Esperance   F  2022
# 2                              Karratha   M  2021
# 3                Cacimba do Padre Beach   M  2021
# 4      New Smyrna Beach, Volusia County   M  2019
# ..                                  ...  ..   ...
# 931        Second Beach, Port St. Johns   M  2012
# 932                    Teahupoo, Tahiti   M  2011
# 933  North Topsail Beach, Onslow County   F  2011
# 934    New Smyrna Beach, Volusia County   M  2011
# 935                       Robberg Beach   M  2011
#
#                                injury    case_number       time   age  \
# 0                 Injury to lower leg   2023.02.19.a    Evening    60
# 1                        Torso bitten   2022.02.10.R    Morning  20.0
# 2                  Laceration to foot   2021.04.24.a  Afternoon   NaN
# 3       Puncture wounds to right hand     2021.01.22    Unknown  52.0
# 4          3 lacerations to left hand   2019.07.29.b  Afternoon  18.0
# ..                                ...            ...        ...   ...
# 931                             FATAL   2012.01.18.b  Afternoon    25
# 932           No injury, board bitten  2011.08.17.b.  Afternoon    32
# 933                      Ankle bitten     2011.06.29    Unknown    10
# 934            Puncture wound to calf   2011.06.06.R    Morning    19
# 935  No injury, board bumped by shark     2011.06.01    Unknown    33
#
#            type                   area           country fatal_y_n  \
# 0    Unprovoked                Florida               USA         N
# 1    Unprovoked      Western Australia         AUSTRALIA         N
# 2    Unprovoked      Western Australia         AUSTRALIA         N
# 3    Unprovoked             Pernambuco            BRAZIL         N
# 4    Unprovoked                Florida               USA         N
# ..          ...                    ...               ...       ...
# 931  Unprovoked  Eastern Cape Province      SOUTH AFRICA         Y
# 932  Unprovoked        Society Islands  FRENCH POLYNESIA         N
# 933  Unprovoked         North Carolina               USA         N
# 934  Unprovoked                Florida               USA         N
# 935  Unprovoked  Western Cape Province      SOUTH AFRICA         N
#
#          species  index_original
# 0        unknown               0
# 1    great white               2
# 2        unknown               3
# 3        unknown               4
# 4        unknown               5
# ..           ...             ...
# 931         bull             995
# 932         reef             996
# 933         bull             997
# 934      unknown             998
# 935  great white             999
#
# [936 rows x 15 columns]

# %% [markdown]
# ## Split up the case number to get the exact date

# %%
from datetime import datetime

# %%
for t in df_real["case_number"]:
    s = t.split(".")
    if pd.isna(t):  # Check for nan
        print("ah")
    if len(s[0]) != 4:
        print(t)
    elif len(s[1]) != 2:
        print(t)
    elif len(s[2]) != 2:
        print (t)
# Out:
# 1988.04.15a
# 1951.09.02-R
# 518.04.00.R
# ND-0124
# ND.0017
# ND.0014
# ND.0006
# 2023.02,04
# 336BC
# ND-0149
# ND-0109
# ND.0091
# ND.0062
# ND.0022
# ND.0018
# ND.0010
# ND.0005
# ND-0135
# ND-0127
# ND.0094
# ND.0051
# ND.0049
# ND.0042
# ND.0034
# ND.0024
# ND-0133
# ND-0113
# ND.0104
# ND.0085
# ND.0082
# ND.0081
# ND.0078
# ND.0043
# ND.0013
# ND.0003

# %%
def grab_date(n):
    l = n.split(".")
    date = f"{l[1]}/{l[2]}/{l[0]}"
    return datetime.strptime(date, "%m/%d/%y").date()

# %%
df_real["date"] = df_real["case_number"].apply(lambda x: grab_date(x))
df_real
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/jennifershulyak/Desktop/Data_Bootcamp_2022/shark_attacks/setup.ipynb Cell 42 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/jennifershulyak/Desktop/Data_Bootcamp_2022/shark_attacks/setup.ipynb#X62sZmlsZQ%3D%3D?line=0'>1</a> df_real["date"] = df_real["case_number"].apply(lambda x: grab_date(x))
#       <a href='vscode-notebook-cell:/Users/jennifershulyak/Desktop/Data_Bootcamp_2022/shark_attacks/setup.ipynb#X62sZmlsZQ%3D%3D?line=1'>2</a> df_real
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# /Users/jennifershulyak/Desktop/Data_Bootcamp_2022/shark_attacks/setup.ipynb Cell 42 in <lambda>(x)
# ----> <a href='vscode-notebook-cell:/Users/jennifershulyak/Desktop/Data_Bootcamp_2022/shark_attacks/setup.ipynb#X62sZmlsZQ%3D%3D?line=0'>1</a> df_real["date"] = df_real["case_number"].apply(lambda x: grab_date(x))
#       <a href='vscode-notebook-cell:/Users/jennifershulyak/Desktop/Data_Bootcamp_2022/shark_attacks/setup.ipynb#X62sZmlsZQ%3D%3D?line=1'>2</a> df_real
#
# /Users/jennifershulyak/Desktop/Data_Bootcamp_2022/shark_attacks/setup.ipynb Cell 42 in grab_date(n)
#       <a href='vscode-notebook-cell:/Users/jennifershulyak/Desktop/Data_Bootcamp_2022/shark_attacks/setup.ipynb#X62sZmlsZQ%3D%3D?line=1'>2</a> l = n.split(".")
#       <a href='vscode-notebook-cell:/Users/jennifershulyak/Desktop/Data_Bootcamp_2022/shark_attacks/setup.ipynb#X62sZmlsZQ%3D%3D?line=2'>3</a> date = f"{l[1]}/{l[2]}/{l[0]}"
# ----> <a href='vscode-notebook-cell:/Users/jennifershulyak/Desktop/Data_Bootcamp_2022/shark_attacks/setup.ipynb#X62sZmlsZQ%3D%3D?line=3'>4</a> return datetime.strptime(date, "%m/%d/%y").date()
#
# File ~/opt/anaconda3/lib/python3.9/_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File ~/opt/anaconda3/lib/python3.9/_strptime.py:352, in _strptime(data_string, format)
#     349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
# --> 352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#     355 iso_year = year = None
#     356 month = day = 1
#
# ValueError: unconverted data remains: 23

# %% [markdown]
# ## Clean up the sex

# %%
df_real["sex"].unique()
# Out:
# array(['M', 'F', nan, 'lli', '.'], dtype=object)

# %%
def clean_sex(item):
    if pd.isna(item):
        return "Unknown"
    elif item not in ["M", "F"]:
        return "Unknown"
    return item

# %%
df_real["sex"] = df_real["sex"].apply(lambda x: clean_sex(x))

# %% [markdown]
# # Export!

# %%
df_real.to_csv("Resources/shark_clean.csv")
